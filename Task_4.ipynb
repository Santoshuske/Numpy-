# %% [markdown]
# <a href="https://colab.research.google.com/github/Santoshuske/Numpy-/blob/main/Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/My Drive/Colab Notebooks/dataset')

# %%
data1 = pd.read_csv("college_1.csv")

# %%
data1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
data2 = pd.read_csv("college_2.csv")

# %%
data2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
data = pd.concat([data1,data2], axis = 0) # joing the two dataframes
data1.shape, data2.shape
# Out:
# ((84, 7), (35, 9))

# %%
data.shape
# Out:
# (119, 9)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data.isnull().sum()
# Out:
# Name                       0
# python                     0
# mysql                      0
# Previous Geekions          0
# CodeKata Score             0
# Department                 0
# Rising                     0
# python_en                 84
# computational_thinking    84
# dtype: int64

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    119 non-null    object
#  1   python                  119 non-null    float64
#  2   mysql                   119 non-null    float64
#  3   Previous Geekions       119 non-null    int64
#  4   CodeKata Score          119 non-null    int64
#  5   Department              119 non-null    object
#  6   Rising                  119 non-null    int64
#  7   python_en               35 non-null     float64
#  8   computational_thinking  35 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 9.3+ KB

# %% [markdown]
# # consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
df=data.loc[data["CodeKata Score"]>15000]

# %%
df
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani    82.0   20.0              24500           24500
# 1    V.JEEVITHA     82.0   20.0              21740           21740
# 2    HEMAVATHI.R   100.0  100.0              19680           19680
# 0  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        NaN
# 1        Computer Science and Engineering       0        NaN
# 2        Computer Science and Engineering       0        NaN
# 0  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 0                     9.0

# %%
df.to_csv('expectations.csv')

# %%
d1 = pd.read_csv("expectations.csv")

# %%
d1
# Out:
#    Unnamed: 0           Name  python  mysql  Previous Geekions  \
# 0           0      A.Dharani    82.0   20.0              24500
# 1           1    V.JEEVITHA     82.0   20.0              21740
# 2           2    HEMAVATHI.R   100.0  100.0              19680
# 3           0  ASHOK KUMAR K   100.0   31.0              19400
#
#    CodeKata Score                              Department  Rising  python_en  \
# 0           24500        Computer Science and Engineering       0        NaN
# 1           21740        Computer Science and Engineering       0        NaN
# 2           19680        Computer Science and Engineering       0        NaN
# 3           19400  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     9.0

# %% [markdown]
# # if 10000<codekata score<15000 (Reached_expectations.csv)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
df1=data.loc[(data['CodeKata Score']<15000) & (data['CodeKata Score']>10000)]

# %%
df1
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 3           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 3                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %%
df1.to_csv('Reached_expectations.csv')

# %%
d2= pd.read_csv("Reached_expectations.csv")

# %%
d2
# Out:
#    Unnamed: 0               Name  python  mysql  Previous Geekions  \
# 0           3        Mugunthan S   100.0   47.0              10610
# 1           1            Chandru     0.0    0.0              14150
# 2           2  Ganesh Ramkumar R    -1.0   24.0               8790
# 3           3    Bodipudi Harini    -1.0   35.0              10040
#
#    CodeKata Score                                 Department  Rising  \
# 0           10610           Computer Science and Engineering       0
# 1           14490           Computer Science and Engineering     340
# 2           10790           Computer Science and Engineering    2000
# 3           10040  Electronics and Communication Engineering       0
#
#    python_en  computational_thinking
# 0        NaN                     NaN
# 1       20.0                     0.0
# 2       55.0                     6.0
# 3        0.0                    -1.0

# %% [markdown]
# # if 7000<codekata score<10000 (Needs_Improvement.csv)

# %%
df2=data.loc[(data['CodeKata Score']<10000) & (data['CodeKata Score']>7000)]

# %%
df2
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4              Sathammai.S   100.0    8.0               8980            8980
# 5             NIVEESHWAR S   100.0    0.0               8200            8200
# 6            KALAIARASAN K    85.0   47.0               7750            7880
# 7     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %%
df2.to_csv('Needs_Improvement.csv')

# %%
d3= pd.read_csv("Needs_Improvement.csv")

# %%
d3
# Out:
#     Unnamed: 0                    Name  python  mysql  Previous Geekions  \
# 0            4             Sathammai.S   100.0    8.0               8980
# 1            5            NIVEESHWAR S   100.0    0.0               8200
# 2            6           KALAIARASAN K    85.0   47.0               7750
# 3            7    MOHAMED ZUBAIR AHMED    82.0    4.0               7020
# 4            4               VIINU V P    -1.0   24.0               9150
# 5            5              Poojitha Y     0.0   35.0               7210
# 6            6  Gowtham Chandrasekaran    -1.0    0.0               7250
# 7            7               Gowtham R    -1.0    4.0               8650
# 8            8                shifak N    58.0    0.0               5180
# 9            9                 Balaji     -1.0   20.0               6170
# 10          10                Rushitha    -1.0   62.0               7470
# 11          11    Balaraman Muthupandi    -1.0    0.0               7670
# ...

# %% [markdown]
# # if codekate score < 7000 (Unsatisfactory.csv)

# %%
df3=data.loc[(data['CodeKata Score']<7000)]

# %%
df3
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 30    praveen raj j    24.0   0.00               2380            2380
# 31       AMARNATH D    -1.0  12.00               1890            1890
# 32             bala    32.0   0.00               1720            1720
# 33             XY Z    -1.0  -1.00                  0               0
# 34        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %%
df3.to_csv('Unsatisfactory.csv')

# %%
d4= pd.read_csv("Unsatisfactory.csv")

# %%
d4
# Out:
#     Unnamed: 0             Name  python  mysql  Previous Geekions  \
# 0            8       J.SUGANTHI    27.0  50.00               5860
# 1            9     thamizhpaana    29.0   0.00               5500
# 2           10  Iyappan Samiraj    50.0  24.00               5400
# 3           11     Ponniyamma.R   100.0  11.25               5380
# 4           12        SABAPATHI   100.0   0.00               5280
# ..         ...              ...     ...    ...                ...
# 88          30    praveen raj j    24.0   0.00               2380
# 89          31       AMARNATH D    -1.0  12.00               1890
# 90          32             bala    32.0   0.00               1720
# 91          33             XY Z    -1.0  -1.00                  0
# 92          34        Hariharan    -1.0  -1.00                  0
#
#     CodeKata Score                                 Department  Rising  \
# 0             5860  Electronics and Communication Engineering       0
# ...

# %%
d4.shape
# Out:
# (93, 10)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data_mean = data[["Previous Geekions","CodeKata Score"]].mean()

# %%
data_mean
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %%
df=data.head(n=10)
df
# Out:
#                    Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0             A.Dharani    82.0   20.0              24500           24500
# 1           V.JEEVITHA     82.0   20.0              21740           21740
# 2           HEMAVATHI.R   100.0  100.0              19680           19680
# 3           Mugunthan S   100.0   47.0              10610           10610
# 4           Sathammai.S   100.0    8.0               8980            8980
# 5          NIVEESHWAR S   100.0    0.0               8200            8200
# 6         KALAIARASAN K    85.0   47.0               7750            7880
# 7  MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 8            J.SUGANTHI    27.0   50.0               5860            5860
# 9          thamizhpaana    29.0    0.0               5500            5500
#
#                                   Department  Rising  python_en  \
# 0           Computer Science and Engineering       0        NaN
# ...

# %%
import seaborn as sns
sns.barplot(x = 'Previous Geekions',
            y = 'CodeKata Score',
            data = df)
 
# Show the plot
plt.show()

# %% [markdown]
# ###### No of students participated

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data.python.value_counts().sum()
# Out:
# 119

# %%
data.mysql.value_counts().sum()
# Out:
# 119

# %%
data.count(axis=0)
# Out:
# Name                      119
# python                    119
# mysql                     119
# Previous Geekions         119
# CodeKata Score            119
# Department                119
# Rising                    119
# python_en                  35
# computational_thinking     35
# dtype: int64

# %%
data.count(axis=1)
# Out:
# 0     7
# 1     7
# 2     7
# 3     7
# 4     7
#      ..
# 30    9
# 31    9
# 32    9
# 33    9
# 34    9
# Length: 119, dtype: int64

# %%
data.python_en.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 30    -1.0
# 31    52.0
# 32    49.0
# 33    20.0
# 34    -1.0
# Name: python_en, Length: 119, dtype: float64>

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data_python_mean = data[["python"]].mean()
data_python_mean
# Out:
# python    54.352941
# dtype: float64

# %%
data_mysql_mean = data[["mysql"]].mean()
data_mysql_mean
# Out:
# mysql    23.5
# dtype: float64

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
data.Rising.unique()
# Out:
# array([   0,  130,  340, 2000, 1760, 1700, 3140, 1990,  620,  380,  690,
#        1540,  560, 1360,  320,  840, 1340, 1000,   30, 1830,  770,  580])

# %%
data_Rising_star=data.loc[(data['Rising']>=2000)]
data_Rising_star
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 8            shifak N    58.0    0.0               5180            8320
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                 Department  Rising  python_en  \
# 2         Computer Science and Engineering    2000       55.0
# 8   Electronics and Electrical Engineering    3140        0.0
# 18        Computer Science and Engineering    2000       -1.0
#
#     computational_thinking
# 2                      6.0
# 8                      0.0
# 18                     0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
data_Shininig_star=data.loc[(data['CodeKata Score']>=19500)]
data_Shininig_star
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
data.Department.unique()
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
data.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %%
Department=data['Department'].head()
Department
# Out:
# 0    Computer Science and Engineering
# 1    Computer Science and Engineering
# 2    Computer Science and Engineering
# 3    Computer Science and Engineering
# 4    Computer Science and Engineering
# Name: Department, dtype: object

# %%
codekatascore=data['CodeKata Score'].head()
codekatascore
# Out:
# 0    24500
# 1    21740
# 2    19680
# 3    10610
# 4     8980
# Name: CodeKata Score, dtype: int64

# %%
gk = data.groupby('Department')
gk.first()
# Out:
#                                                     Name  python  mysql  \
# Department
# Computer Science and Engineering               A.Dharani    82.0   20.0
# Electronics and Communication Engineering  KALAIARASAN K    85.0   47.0
# Electronics and Electrical Engineering        k.parvathi   100.0  100.0
#
#                                            Previous Geekions  CodeKata Score  \
# Department
# Computer Science and Engineering                       24500           24500
# Electronics and Communication Engineering               7750            7880
# Electronics and Electrical Engineering                   260             260
#
#                                            Rising  python_en  \
# Department
# Computer Science and Engineering                0       20.0
# Electronics and Communication Engineering     130        0.0
# Electronics and Electrical Engineering          0        0.0
#
#                                            computational_thinking
# Department
# ...

# %%
CS_Dpt=gk.get_group('Computer Science and Engineering')
CS_Dpt
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0           A.Dharani    82.0   20.0              24500           24500
# 1         V.JEEVITHA     82.0   20.0              21740           21740
# 2         HEMAVATHI.R   100.0  100.0              19680           19680
# 3         Mugunthan S   100.0   47.0              10610           10610
# 4         Sathammai.S   100.0    8.0               8980            8980
# ..                ...     ...    ...                ...             ...
# 27  Vimalesh Fernando    -1.0    0.0               4170            4170
# 28      M.Karthikeyan    -1.0    4.0               4020            4020
# 30      praveen raj j    24.0    0.0               2380            2380
# 33               XY Z    -1.0   -1.0                  0               0
# 34          Hariharan    -1.0   -1.0                  0               0
#
#                           Department  Rising  python_en  \
# ...

# %%
csdptmean=CS_Dpt[['CodeKata Score']].mean()
csdptmean
# Out:
# CodeKata Score    5079.761905
# dtype: float64

# %%
data_mysql_mean = data[["mysql"]].mean()
data_mysql_mean

# %%
EC_Dpt=gk.get_group('Electronics and Communication Engineering')
EC_Dpt
# Out:
#                           Name  python   mysql  Previous Geekions  \
# 6                KALAIARASAN K    85.0   47.00               7750
# 8                   J.SUGANTHI    27.0   50.00               5860
# 10             Iyappan Samiraj    50.0   24.00               5400
# 14             Melvin Dukles.R    56.0   20.00               4800
# 17                 v.vithyasri   100.0   12.00               4370
# 18          Abirami Anbazhagan   100.0    0.00               4320
# 21                kamalishwari    32.0   20.00               3665
# 25                   Tpavithra   100.0   24.00               3200
# 27                    shankari    87.5   20.00               3000
# 32                  SarumathiR    16.0   35.00               2240
# 35                    Barath D    74.0    4.00               1910
# 39                     vignesh    85.0    0.00               1740
# 42                   ABIRAMI.S    82.0    0.00               1580
# ...

# %%
Ecdptmean=EC_Dpt[['CodeKata Score']].mean()
Ecdptmean
# Out:
# CodeKata Score    2777.820513
# dtype: float64

# %%
EE_Dpt=gk.get_group('Electronics and Electrical Engineering')
EE_Dpt
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 64       k.parvathi   100.0  100.0                260             260
# 71      m.keerthana    97.5    0.0                120             120
# 72       Subhashini   100.0    4.0                120             120
# 74  J.Bhuvaneshwari   100.0   20.0                100             100
# 75         santhosh    82.0   12.0                 60              60
# 77       J.JAYANTHI   100.0  100.0                 40              40
# 78     vikneshwaran   100.0    4.0                 40              40
# 79     KarthikeyanS    45.0    0.0                  0               0
# 80         BARATH.P    29.0    0.0                  0               0
# 81    N.Ajith kumar    82.0    0.0                  0               0
# 82     mohamed nabi     0.0    0.0                  0               0
# 83   yaser ahamed.A     0.0   27.0                  0               0
# ...

# %%
EEdptmean=EE_Dpt[['CodeKata Score']].mean()
EEdptmean
# Out:
# CodeKata Score    3164.705882
# dtype: float64

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'CS', 'EC', 'EE'
sizes = [5079.761905, 2777.820513,3164.705882]
explode = (0, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
x = data.groupby('Name')['CodeKata Score'].mean().sort_values().tail(15)
x
# Out:
# Name
# NIVEESHWAR S               8200.0
# shifak N                   8320.0
# Gowtham R                  8650.0
# Gowtham Chandrasekaran     8950.0
#  Poojitha Y                8970.0
# Sathammai.S                8980.0
# VIINU V P                  9150.0
# Bodipudi Harini           10040.0
# Mugunthan S               10610.0
# Ganesh Ramkumar R         10790.0
# Chandru                   14490.0
# ASHOK KUMAR K             19400.0
# HEMAVATHI.R               19680.0
# V.JEEVITHA                21740.0
# A.Dharani                 24500.0
# Name: CodeKata Score, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
x.plot(kind='barh')

# %%
C = CS_Dpt.groupby('Name')['CodeKata Score'].mean().sort_values().tail(15)
C
# Out:
# Name
# Suryarajan S               7550.0
# Rahul Raj K                7640.0
# SRIRAMKUMAR B              7940.0
# Balaraman Muthupandi       8050.0
# Rushitha                   8090.0
# NIVEESHWAR S               8200.0
# Gowtham Chandrasekaran     8950.0
#  Poojitha Y                8970.0
# Sathammai.S                8980.0
# Mugunthan S               10610.0
# Ganesh Ramkumar R         10790.0
# Chandru                   14490.0
# HEMAVATHI.R               19680.0
# V.JEEVITHA                21740.0
# A.Dharani                 24500.0
# Name: CodeKata Score, dtype: float64

# %%
C.plot(kind='barh')

# %%
EC = EC_Dpt.groupby('Name')['CodeKata Score'].mean().sort_values().tail(15)
EC
# Out:
# Name
# shankari               3000.0
# Tpavithra              3200.0
# Abishak s              3220.0
# kamalishwari           3665.0
# Abirami Anbazhagan     4320.0
# v.vithyasri            4370.0
# Melvin Dukles.R        4800.0
# P.GOVARDHANAN          5050.0
# Iyappan Samiraj        5400.0
# J.SUGANTHI             5860.0
# Guhan S                7630.0
# Praneetha              7730.0
# KALAIARASAN K          7880.0
# Gowtham R              8650.0
# Bodipudi Harini       10040.0
# Name: CodeKata Score, dtype: float64

# %%
EC.plot(kind='barh')

# %%
EE = EE_Dpt.groupby('Name')['CodeKata Score'].mean().sort_values().tail(15)
EE
# Out:
# Name
# mohamed nabi           0.0
# KarthikeyanS           0.0
# N.Ajith kumar          0.0
# J.JAYANTHI            40.0
# vikneshwaran          40.0
# santhosh              60.0
# J.Bhuvaneshwari      100.0
# m.keerthana          120.0
# Subhashini           120.0
# k.parvathi           260.0
# JPradhap            8030.0
# Balaji              8160.0
# shifak N            8320.0
# VIINU V P           9150.0
# ASHOK KUMAR K      19400.0
# Name: CodeKata Score, dtype: float64

# %%
EE.plot(kind='barh')

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...
